# %% [markdown]
# # Introduction to Python for Image Processing
# * Python packages needed for image processing: numpy, scipy, opencv-python.
# * IDE suitable for Windows: jupyter notebook, MS visual studio
# * IDE suitable for Linux: jupyter notebook, PyCharm
#
# #  Import packages
# * **numpy package**: Numerical computing package for linear algebra and matrix computing
# * **cv2 package**: OpenCV wrapper package in python for image processing and computer vision
# * **matplotlib.pyplot**: pyplot image package for plotting and showing image and plots

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# # Loading Image

# %%
img = cv.imread('mammogram_digital_Xray (1).tif', cv.IMREAD_GRAYSCALE)
print('Image Size is {}'.format(img.shape))
plt.figure(figsize=(10,10))
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.show()
# Out:
# Image Size is (571, 482)

# %%
print (img)
# Out:
# [[ 23  30  32 ... 238 238 238]
#  [ 38  26  39 ... 238 238 238]
#  [ 35  21  43 ... 238 238 238]
#  ...
#  [ 31  31  29 ...  30  30  30]
#  [ 31  31  29 ...  30  30  30]
#  [ 31  31  29 ...  30  30  30]]

# %%
print("Max of image is {}".format(np.max(img)))
print("Min of image is {}".format(np.min(img)))
# Out:
# Max of image is 255
# Min of image is 21

# %% [markdown]
# # Image Negatives
# * Let $L$ be maximum intensity in **img**
# * Negative image: **neg_img** = $L - 1 - $ **img**

# %%
L = 255
neg_img = L - 1 - img
plt.figure(figsize=(10,10))
plt.imshow(neg_img, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
# Out:
# (-0.5, 481.5, 570.5, -0.5)

# %% [markdown]
# # Image Threshold
# * Let $Th$ be threshold in **img**
# * Negative image: **thresh_img** = **img** $ <= Th$

# %%
Th = 150
thresh_img = (img >= Th) * 255.0
plt.figure(figsize=(10,10))
plt.imshow(thresh_img, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
# Out:
# (-0.5, 481.5, 570.5, -0.5)
